# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviupadhyay1517/Hypothesis-Testing-/blob/main/exam_performance_of_single_mean_bp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study
# A university professor wants to determine whether the average exam score for a recent class is significantly less than the passing score of 50 marks. This analysis will help the professor assess if additional teaching interventions are required to improve student performance. [Data: exam_performance.xlsx]

# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp,shapiro

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Reading the data

# %%
df = pd.read_excel('/content/drive/MyDrive/Classroom/FTN Batch 10/T test One sample/exam_performance (1).xlsx')

# %% [markdown]
# # Exploratory Analysis

# %%
df.dtypes   # type if variables in the dataframe
# Out:
# Student_ID     object
# Exam_Score    float64
# dtype: object

# %%
df.isnull().sum()   # Counts the number of missing values
# Out:
# Student_ID    0
# Exam_Score    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Student_ID', 'Exam_Score'], dtype='object')

# %%
df.head()        ## Viewing first few observations
# Out:
#   Student_ID  Exam_Score
# 0         S1   54.440924
# 1         S2   55.247228
# 2         S3   48.331679
# 3         S4   44.177282
# 4         S5   42.539134

# %%
plt.boxplot(df['Exam_Score'])   # Box plot
plt.show()

# %%
df.describe()    ## Decriptive statistics of the numeric variables
# Out:
#        Exam_Score
# count  100.000000
# mean    47.747118
# std      4.720067
# min     33.821046
# 25%     44.954306
# 50%     48.052155
# 75%     50.782746
# max     59.945560

# %% [markdown]
# # Normality Check

# %%
# Shapiro test

shapiro(df['Exam_Score'])
# Out:
# ShapiroResult(statistic=np.float64(0.9897551665807611), pvalue=np.float64(0.6448197231951385))

# %%
# qq plot
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

qqplot(df['Exam_Score'],line='s')
plt.show()

# %% [markdown]
# # t test for single sample

# %%
ttest1 = ttest_1samp(df['Exam_Score'],50,alternative='less')
ttest1
# Out:
# TtestResult(statistic=np.float64(-4.772987380604716), pvalue=np.float64(3.137925060426659e-06), df=np.int64(99))
