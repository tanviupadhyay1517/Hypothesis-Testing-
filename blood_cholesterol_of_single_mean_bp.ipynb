# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviupadhyay1517/Hypothesis-Testing-/blob/main/blood_cholesterol_of_single_mean_bp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study
# Assume that the average blood cholesterol level for a healthy 30-year-old male is 200 mg/100 ml. Blood cholesterol readings are obtained for a group consisting of eleven 30-year-old men who have had a heart attack within the last month. The blood cholesterol scores of the eleven men are:
# 230, 167, 250, 345, 442, 190, 200, 248, 289, 262, 301.
# Can one conclude that the average cholesterol level of the population represented by the sample (i.e., recent male heart attack victims) is some value other than 200?

# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp,shapiro

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Reading the data

# %%
# df = pd.read_excel('/content/drive/MyDrive/Classroom/FTN Batch 10/T test One sample/customer_service (1).xlsx')

# %%
df = pd.DataFrame({
    'Cholesterol': [230, 167, 250, 345, 442, 190, 200, 248, 289, 262, 301]
})

# %% [markdown]
# # Exploratory Analysis

# %%
df.dtypes   # type if variables in the dataframe
# Out:
# Cholesterol    int64
# dtype: object

# %%
df.isnull().sum()   # Counts the number of missing values
# Out:
# Cholesterol    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Cholesterol'], dtype='object')

# %%
df.head()        ## Viewing first few observations
# Out:
#    Cholesterol
# 0          230
# 1          167
# 2          250
# 3          345
# 4          442

# %%
plt.boxplot(df['Cholesterol'])   # Box plot
plt.show()

# %%
df.describe()    ## Decriptive statistics of the numeric variables
# Out:
#        Cholesterol
# count    11.000000
# mean    265.818182
# std      77.971557
# min     167.000000
# 25%     215.000000
# 50%     250.000000
# 75%     295.000000
# max     442.000000

# %% [markdown]
# # Normality Check

# %%
# Shapiro test

shapiro(df['Cholesterol'])
# Out:
# ShapiroResult(statistic=np.float64(0.9289516731144695), pvalue=np.float64(0.4003459934695628))

# %%
# qq plot
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

qqplot(df['Cholesterol'],line='s')
plt.show()

# %% [markdown]
# # t test for single sample

# %%
ttest1 = ttest_1samp(df['Cholesterol'],200,alternative='two-sided')
ttest1
# Out:
# TtestResult(statistic=np.float64(2.7996646858648884), pvalue=np.float64(0.018805362878453333), df=np.int64(10))
