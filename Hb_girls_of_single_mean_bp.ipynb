# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviupadhyay1517/Hypothesis-Testing-/blob/main/Hb_girls_of_single_mean_bp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study
# A researcher is investigating hemoglobin levels of schoolgirls in a particular area. 15 schoolgirls were randomly selected, and their hemoglobin level is as follows. Does the data reveal that average hemoglobin level among school girls is more than 11.5? Use 5 % level of significance.  (File Name: Hb_girls.xlsx)

# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp,shapiro

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Reading the data

# %%
df = pd.read_excel('/content/drive/MyDrive/Classroom/FTN Batch 10/T test One sample/Hb_girls (1).xlsx')

# %% [markdown]
# # Exploratory Analysis

# %%
df.dtypes   # type if variables in the dataframe
# Out:
# Hb    float64
# dtype: object

# %%
df.isnull().sum()   # Counts the number of missing values
# Out:
# Hb    0
# dtype: int64

# %%
df.head()        ## Viewing first few observations
# Out:
#      Hb
# 0  11.9
# 1  11.5
# 2  11.1
# 3  10.6
# 4  10.4

# %%
df.describe()    ## Decriptive statistics of the numeric variables
# Out:
#               Hb
# count  15.000000
# mean   11.340000
# std     0.476295
# min    10.400000
# 25%    11.000000
# 50%    11.500000
# 75%    11.650000
# max    12.000000

# %%
plt.boxplot(df['Hb'])   # Box plot
plt.show()

# %% [markdown]
# # Normality Check

# %%
# Shapiro test

shapiro(df['Hb'])
# Out:
# ShapiroResult(statistic=np.float64(0.9487527088008747), pvalue=np.float64(0.5050250706814068))

# %%
# qq plot
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

qqplot(df['Hb'],line='s')
plt.show()

# %% [markdown]
# # t test for single sample

# %%
ttest1 = ttest_1samp(df['Hb'],11.5,alternative='greater')
ttest1
# Out:
# TtestResult(statistic=np.float64(-1.3010362078381204), pvalue=np.float64(0.8928738339091483), df=np.int64(14))
