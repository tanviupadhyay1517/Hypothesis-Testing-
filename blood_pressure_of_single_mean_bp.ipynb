# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviupadhyay1517/Hypothesis-Testing-/blob/main/blood_pressure_of_single_mean_bp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study
# A medical researcher obtains the systolic blood pressure readings (in mm Hg) in the accompanying list from a sample of women aged 18- 24 who have a new strain of viral infection.
# 134.9, 78.7, 108.9, 133.0, 123.7, 96.1, 126.9, 89.8, 132.0, 134.7, 132.1, 121.7, 112.3, 150.2, 158.3, 154.4
# Healthy women in that age group have readings that are normally distributed with a mean blood pressure of 114.8.Test the claim that the sample comes from a healthy women population in that age group. [Data:blood_pressure.xlsx]

# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp,shapiro

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Reading the data

# %%
df = pd.read_excel('/content/drive/MyDrive/Classroom/FTN Batch 10/T test One sample/blood_pressure.xlsx')

# %% [markdown]
# # Exploratory Analysis

# %%
df.dtypes   # type if variables in the dataframe
# Out:
# bp    float64
# dtype: object

# %%
df.isnull().sum()   # Counts the number of missing values
# Out:
# bp    0
# dtype: int64

# %%
df.head()        ## Viewing first few observations
# Out:
#       bp
# 0  134.9
# 1   78.7
# 2  108.9
# 3  133.0
# 4  123.7

# %%
df.describe()    ## Decriptive statistics of the numeric variables
# Out:
#                bp
# count   16.000000
# mean   124.231250
# std     22.522543
# min     78.700000
# 25%    111.450000
# 50%    129.450000
# 75%    134.750000
# max    158.300000

# %%
plt.boxplot(df['bp'])   # Box plot
plt.show()

# %% [markdown]
# # Normality Check

# %%
# Shapiro test

shapiro(df['bp'])
# Out:
# ShapiroResult(statistic=np.float64(0.9529529790515654), pvalue=np.float64(0.5378656107778705))

# %%
# qq plot
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

qqplot(df['bp'],line='s')
plt.show()

# %% [markdown]
# # t test for single sample

# %%
ttest1 = ttest_1samp(df['bp'],114.8,alternative='two-sided')
ttest1
# Out:
# TtestResult(statistic=np.float64(1.674988452093638), pvalue=np.float64(0.1146521837891214), df=np.int64(15))
