# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviupadhyay1517/Hypothesis-Testing-/blob/main/Customer_service_of_single_mean_bp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study
# A customer service department wants to assess whether the average processing time for handling customer service calls deviates significantly from the company’s target of 15 minutes. This analysis helps identify inefficiencies or opportunities to streamline processes. [Data: customer_service.xlsx]

# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp,shapiro

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Reading the data

# %%
df = pd.read_excel('/content/drive/MyDrive/Classroom/FTN Batch 10/T test One sample/customer_service (1).xlsx')

# %% [markdown]
# # Exploratory Analysis

# %%
df.dtypes   # type if variables in the dataframe
# Out:
# Call_ID             object
# Processing_Time    float64
# dtype: object

# %%
df.isnull().sum()   # Counts the number of missing values
# Out:
# Call_ID            0
# Processing_Time    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Call_ID', 'Processing_Time'], dtype='object')

# %%
df.head()        ## Viewing first few observations
# Out:
#   Call_ID  Processing_Time
# 0      C1        15.284124
# 1      C2        18.750073
# 2      C3        12.205865
# 3      C4        17.977132
# 4      C5        14.222536

# %%
plt.boxplot(df['Processing_Time'])   # Box plot
plt.show()

# %%
df.describe()    ## Decriptive statistics of the numeric variables
# Out:
#        Processing_Time
# count       120.000000
# mean         14.541389
# std           3.221877
# min           4.182742
# 25%          12.607891
# 50%          14.435258
# 75%          16.633555
# max          21.971829

# %% [markdown]
# # Normality Check

# %%
# Shapiro test

shapiro(df['Processing_Time'])
# Out:
# ShapiroResult(statistic=np.float64(0.9878957219687983), pvalue=np.float64(0.36628718869438825))

# %%
# qq plot
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

qqplot(df['Processing_Time'],line='s')
plt.show()

# %% [markdown]
# # t test for single sample

# %%
ttest1 = ttest_1samp(df['Processing_Time'],15,alternative='two-sided')
ttest1
# Out:
# TtestResult(statistic=np.float64(-1.5592870711689026), pvalue=np.float64(0.12158402204999491), df=np.int64(119))
