# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviupadhyay1517/Hypothesis-Testing-/blob/main/Paired_t_test_Jump.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Case Study:**
# Suppose the coach of a basketball team is preparing the team for a tournament next month. One of the training objectives is to maximize the vertical jump of the players, so player’s maximum vertical jump (in inches) before and after the training program was measured. Can the coach be assured that the team make progress? (File Name: jump.xlsx)

# %%
# Import necessary packages
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read data
df1 = pd.read_excel('/content/drive/MyDrive/Classroom/FTN Batch 10/T test Two sample/jump.xlsx')

# %% [markdown]
# # Exploratory Analysis

# %%
df1.columns
# Out:
# Index(['Before', 'After'], dtype='object')

# %%
df1.head()                                  # Viewing first few observations of the data
# Out:
#    Before  After
# 0      22     24
# 1      20     22
# 2      19     19
# 3      24     22
# 4      25     28

# %%
df1.describe()                              # Descriptive statistics
# Out:
#           Before      After
# count  20.000000  20.000000
# mean   23.150000  24.100000
# std     3.745524   4.011825
# min    16.000000  17.000000
# 25%    19.750000  21.500000
# 50%    24.000000  24.500000
# 75%    25.000000  27.250000
# max    30.000000  30.000000

# %%
# Taking difference
df1['errors_diff'] = df1['After'] - df1['Before']
df1['errors_diff'].describe()
# Out:
# count    20.000000
# mean      0.950000
# std       1.316894
# min      -2.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       3.000000
# Name: errors_diff, dtype: float64

# %%
# Boxplot
plt.figure(figsize=(8, 6))
plt.boxplot(df1['errors_diff'])
plt.show()

# %%
# Checking Normality using Shapiro test
Shapiro1=stats.shapiro(df1['errors_diff'])
Shapiro1
# Out:
# ShapiroResult(statistic=np.float64(0.8970372772520514), pvalue=np.float64(0.036300583653832104))

# %%
# Checking Normality using Q-Q plot
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

qqplot(df1['errors_diff'],line='s')
plt.show()

# %%
# Paired t test / t test for dependent samples

ttest=stats.ttest_rel(df1['After'] , df1['Before'], alternative ='greater')
ttest
# Out:
# TtestResult(statistic=np.float64(3.22617331116718), pvalue=np.float64(0.0022226853522061144), df=np.int64(19))

# %%
print("Average errors before training:", df1['Before'].mean())
print("Average errors after training :", df1['After'].mean())
# Out:
# Average errors before training: 23.15
# Average errors after training : 24.1
