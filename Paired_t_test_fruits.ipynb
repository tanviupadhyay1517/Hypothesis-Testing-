# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviupadhyay1517/Hypothesis-Testing-/blob/main/Paired_t_test_fruits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Case Study:**
# The iron contents of fruits before and after applying farmyard manure was observed. Is there any Significant difference between the mean iron contents in the fruits before & after the farm yarn manure? (File Name: Fruit_iron_content.xlsx)

# %%
# Import necessary packages
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read data
df1 = pd.read_excel('/content/drive/MyDrive/Classroom/FTN Batch 10/T test Two sample/Fruit_iron_content.xlsx')

# %% [markdown]
# # Exploratory Analysis

# %%
df1.columns
# Out:
# Index(['Before ', 'After'], dtype='object')

# %%
df1.head()                                  # Viewing first few observations of the data
# Out:
#    Before   After
# 0      7.7    8.1
# 1      8.5    8.9
# 2      7.2    7.0
# 3      6.3    6.1
# 4      8.1    8.2

# %%
df1.describe()                              # Descriptive statistics
# Out:
#          Before       After
# count  10.000000  10.000000
# mean    7.670000   7.770000
# std     0.941689   1.109605
# min     6.300000   5.800000
# 25%     7.200000   7.250000
# 50%     7.600000   8.050000
# 75%     8.250000   8.575000
# max     9.400000   8.900000

# %%
# Taking difference
df1['errors_diff'] = df1['Before '] - df1['After']
df1['errors_diff'].describe()
# Out:
# count    10.000000
# mean     -0.100000
# std       0.483046
# min      -0.800000
# 25%      -0.400000
# 50%      -0.250000
# 75%       0.200000
# max       0.700000
# Name: errors_diff, dtype: float64

# %%
# Boxplot
plt.figure(figsize=(8, 6))
plt.boxplot(df1['errors_diff'])
plt.show()

# %%
# Checking Normality using Shapiro test
Shapiro1=stats.shapiro(df1['errors_diff'])
Shapiro1
# Out:
# ShapiroResult(statistic=np.float64(0.938477074950778), pvalue=np.float64(0.536195281492514))

# %%
# Checking Normality using Q-Q plot
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

qqplot(df1['errors_diff'],line='s')
plt.show()

# %%
# Paired t test / t test for dependent samples

ttest=stats.ttest_rel(df1['Before '] , df1['After'], alternative ='two-sided')
ttest
# Out:
# TtestResult(statistic=np.float64(-0.6546536707079755), pvalue=np.float64(0.5290641716818766), df=np.int64(9))

# %%
print("Average errors before training:", df1['Before '].mean())
print("Average errors after training :", df1['After'].mean())
# Out:
# Average errors before training: 7.67
# Average errors after training : 7.7700000000000005
